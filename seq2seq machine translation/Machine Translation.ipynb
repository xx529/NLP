# %%
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

# 使用GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SOS_token = 0
EOS_token = 1

# %%
# 主要用于储存单词与id的映射
class Vocabulary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {0: "<SOS>", 1: "<EOS>", 2: "<unk>"}
        self.idx = 3 # Count SOS and EOS

    # 记录word和id之间的映射
    def add_word(self, word):
        if not word in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1
            
    # 将句子进行分词，添加每个单词与id的映射
    def add_sentence(self, sentence):
        for word in sentence.split():
            self.add_word(word)
    
    # 得到某个单词的id
    def __call__(self, word):
        if not word in self.word2idx:
            return 2
        return self.word2idx[word]
    
    # vaocabulary的容量
    def __len__(self):
        return self.idx

# %%
class EncoderRNN(nn.Module):
    # 在构造函数内定义了一个Embedding层和一GRU层，
    def __init__(self, word_size, embedding_dim):
        super(EncoderRNN, self).__init__()
        
        # 定义需要的变量
        self.gru_hidden_size = 4
        self.gru_num_layers = 1
        self.embedding_dim = embedding_dim
        self.gru_h0 = self.initHidden()

        
        # 定义网络
        self.embedding = nn.Embedding(word_size, embedding_dim)
        self.gru = nn.GRU(embedding_dim, self.gru_hidden_size)

    # 前向传播
    def forward(self, x, h):
        embedding = self.embedding(x)
        embedding = embedding.view(1, 1, self.embedding_dim)
        _, h = self.gru(embedding, h)
        return h
    
    # 最终执行函数
    def sample(self,seq_list):
        word_list = torch.LongTensor(seq_list).to(device)
        h = self.gru_h0
        for word_tensor in word_list:
            h = self(word_tensor, h)
        return h

    # 初始化第一层的h0，随机生成一个
    def initHidden(self):
        tensor = torch.Tensor(self.gru_num_layers, 1, self.gru_hidden_size)
        return nn.init.normal_(tensor)

class DecoderRNN(nn.Module):
    def __init__(self, word_size, embedding_dim):
        super(DecoderRNN, self).__init__()
        
        # 定义需要的变量
        self.gru_hidden_size = 4
        self.embedding_dim = embedding_dim
        self.maxlen = 10
        
        # 定义网络
        self.embedding = nn.Embedding(word_size, embedding_dim)
        self.gru = nn.GRU(embedding_dim, self.gru_hidden_size)
        self.linear = nn.Linear(self.gru_hidden_size, word_size)
        self.softmax = nn.LogSoftmax(dim=1)
        
        
    def forward(self, x, s):
        embedding = self.embedding(x)
        embedding = embedding.view(1, 1, self.embedding_dim)
        embedding = F.relu(embedding)
        gru_output, h = self.gru(embedding, s)
        output = self.linear(gru_output[0])
        output = self.softmax(output)
        return output, h

    # pre_hidden即公式中所谓的固定C向量
    def sample(self, pre_hidden):
        inputs = torch.LongTensor([SOS_token]).to(device)
        h = pre_hidden
        res = [SOS_token]
        for i in range(self.maxlen):
            output, h = self(inputs, h)
            top_value, top_index = output.topk(1)
            if top_index.item() == EOS_token:
                res.append(top_index.item())
                break
            else:
                res.append(top_index.item())
            inputs = top_index.squeeze().detach()
            
        return res

# %%
# 处理句子，将句子转换成Tensor
def sentence2tensor(lang, sentence):
    indexes = [lang(word) for word in sentence.split()]
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

# 将(input, target)的pair都转换成Tensor
def pair2tensor(pair):
    input_tensor = sentence2tensor(lan1, pair[0])
    target_tensor = sentence2tensor(lan2, pair[1])
    return (input_tensor, target_tensor)

# 定义句子和Vocabulary类
lan1 = Vocabulary()
lan2 = Vocabulary()

data = [['Hi .', '嗨 。'],
        ['Hi .', '你 好 。'],
        ['Run .', '跑'],
        ['Wait !', '等等 ！'],
        ['Hello !', '你好 。'],
        ['I try .', '让 我 来 。'],
        ['I won !', '我 赢 了 。'],
        ['I am OK .', '我 沒事 。']]

for i,j in data:
    lan1.add_sentence(i)
    lan2.add_sentence(j)
print(len(lan1))
print(len(lan2))

# 定义Encoder和Decoder以及训练的一些参数
import random
learning_rate = 0.001
hidden_size = 256

# 将Encoder, Decoder放到GPU
encoder = EncoderRNN(len(lan1), hidden_size).to(device)
decoder = DecoderRNN(len(lan2), hidden_size).to(device)
# 网络参数 = Encoder参数 + Decoder参数
params = list(encoder.parameters()) + list(decoder.parameters())
# 定义优化器
optimizer = optim.Adam(params, lr=learning_rate)
loss = 0
# NLLLoss = Negative Log Likelihood Loss
criterion = nn.NLLLoss()
# 一共训练多次轮
turns = 200
print_every = 20
print_loss_total = 0
# 将数据random choice，然后转换成 Tensor
training_pairs = [pair2tensor(random.choice(data)) for pair in range(turns)]
# Out:
# 14
# 17

# %%
training_pairs
# Out:
# [(tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[3],
#           [4],
#           [1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[3],
#           [4],
#           [1]]),
#   tensor([[5],
#           [6],
#           [4],
#           [1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[8],
#           [7],
#           [1]]),
#   tensor([[10],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]])),
#  (tensor([[ 9],
#           [11],
#           [ 7],
#           [ 1]]),
#   tensor([[12],
#           [14],
#           [15],
#           [ 4],
#           [ 1]])),
#  (tensor([[6],
#           [7],
#           [1]]),
#   tensor([[8],
#           [9],
#           [1]])),
#  (tensor([[ 9],
#           [10],
#           [ 4],
#           [ 1]]),
#   tensor([[11],
#           [12],
#           [13],
#           [ 4],
#           [ 1]])),
#  (tensor([[ 9],
#           [12],
#           [13],
#           [ 4],
#           [ 1]]),
#   tensor([[12],
#           [16],
#           [ 4],
#           [ 1]])),
#  (tensor([[5],
#           [4],
#           [1]]),
#   tensor([[7],
#           [1]]))]

# %%
# 训练过程
for turn in range(turns):
    optimizer.zero_grad()
    loss = 0
    
    x, y = training_pairs[turn]
    input_length = x.size(0)
    target_length = y.size(0)
#     print(y)
    
    # 初始化Encoder中的h0
    h0 = encoder.gru_h0
    
    # 对input进行Encoder
    for i in range(input_length):
        h0 = encoder(x[i], h0)
    
    # Decoder的一个input <sos>
    decoder_input = torch.LongTensor([SOS_token]).to(device)
    
    h = h0
    for i in range(target_length):
        decoder_output, h= decoder(decoder_input, h)
        top_value, top_index = decoder_output.topk(1)
        decoder_input = top_index.squeeze().detach()
#         print(decoder_output)
#         print(y[i])
        loss += criterion(decoder_output, y[i])
        print(loss)
        if decoder_input.item() == EOS_token:break  
    print_loss_total += loss.item()/target_length
    if (turn+1) % print_every == 0 :
#         print("loss:{loss:,.4f}".format(loss=print_loss_total/print_every))
        print_loss_total = 0
        
    loss.backward()
    optimizer.step()
# Out:
# tensor(3.1511, grad_fn=<AddBackward0>)
# tensor(6.1546, grad_fn=<AddBackward0>)
# tensor(9.3204, grad_fn=<AddBackward0>)
# tensor(2.2798, grad_fn=<AddBackward0>)
# tensor(4.9380, grad_fn=<AddBackward0>)
# tensor(7.9589, grad_fn=<AddBackward0>)
# tensor(10.9707, grad_fn=<AddBackward0>)
# tensor(14.2727, grad_fn=<AddBackward0>)
# tensor(2.6847, grad_fn=<AddBackward0>)
# tensor(5.9708, grad_fn=<AddBackward0>)
# tensor(8.7699, grad_fn=<AddBackward0>)
# tensor(11.3298, grad_fn=<AddBackward0>)
# tensor(2.2344, grad_fn=<AddBackward0>)
# tensor(4.3790, grad_fn=<AddBackward0>)
# tensor(7.3715, grad_fn=<AddBackward0>)
# tensor(9.8709, grad_fn=<AddBackward0>)
# tensor(12.8439, grad_fn=<AddBackward0>)
# tensor(3.0264, grad_fn=<AddBackward0>)
# tensor(5.9113, grad_fn=<AddBackward0>)
# tensor(2.6135, grad_fn=<AddBackward0>)
# tensor(5.9152, grad_fn=<AddBackward0>)
# tensor(8.4243, grad_fn=<AddBackward0>)
# tensor(10.8893, grad_fn=<AddBackward0>)
# tensor(3.0215, grad_fn=<AddBackward0>)
# tensor(5.8215, grad_fn=<AddBackward0>)
# tensor(2.6459, grad_fn=<AddBackward0>)
# tensor(5.3617, grad_fn=<AddBackward0>)
# tensor(7.9977, grad_fn=<AddBackward0>)
# tensor(10.9475, grad_fn=<AddBackward0>)
# tensor(2.9473, grad_fn=<AddBackward0>)
# tensor(6.5841, grad_fn=<AddBackward0>)
# tensor(8.9201, grad_fn=<AddBackward0>)
# tensor(3.3221, grad_fn=<AddBackward0>)
# tensor(5.9214, grad_fn=<AddBackward0>)
# tensor(8.2459, grad_fn=<AddBackward0>)
# tensor(3.3114, grad_fn=<AddBackward0>)
# tensor(5.9071, grad_fn=<AddBackward0>)
# tensor(8.2251, grad_fn=<AddBackward0>)
# tensor(2.5992, grad_fn=<AddBackward0>)
# tensor(5.3613, grad_fn=<AddBackward0>)
# tensor(7.7418, grad_fn=<AddBackward0>)
# tensor(10.3617, grad_fn=<AddBackward0>)
# tensor(2.5582, grad_fn=<AddBackward0>)
# tensor(4.9824, grad_fn=<AddBackward0>)
# tensor(8.3963, grad_fn=<AddBackward0>)
# tensor(10.7067, grad_fn=<AddBackward0>)
# tensor(13.3584, grad_fn=<AddBackward0>)
# tensor(2.6358, grad_fn=<AddBackward0>)
# tensor(5.2392, grad_fn=<AddBackward0>)
# tensor(7.8695, grad_fn=<AddBackward0>)
# tensor(2.6531, grad_fn=<AddBackward0>)
# tensor(5.2487, grad_fn=<AddBackward0>)
# tensor(7.8545, grad_fn=<AddBackward0>)
# tensor(2.4965, grad_fn=<AddBackward0>)
# tensor(5.2364, grad_fn=<AddBackward0>)
# tensor(7.6196, grad_fn=<AddBackward0>)
# tensor(10.1594, grad_fn=<AddBackward0>)
# tensor(2.6889, grad_fn=<AddBackward0>)
# tensor(5.6660, grad_fn=<AddBackward0>)
# tensor(8.7297, grad_fn=<AddBackward0>)
# tensor(2.6030, grad_fn=<AddBackward0>)
# tensor(4.8077, grad_fn=<AddBackward0>)
# tensor(8.2588, grad_fn=<AddBackward0>)
# tensor(10.5707, grad_fn=<AddBackward0>)
# tensor(13.1250, grad_fn=<AddBackward0>)
# tensor(3.0426, grad_fn=<AddBackward0>)
# tensor(5.6185, grad_fn=<AddBackward0>)
# tensor(2.4061, grad_fn=<AddBackward0>)
# tensor(4.9510, grad_fn=<AddBackward0>)
# tensor(7.9507, grad_fn=<AddBackward0>)
# tensor(11.0258, grad_fn=<AddBackward0>)
# tensor(2.9622, grad_fn=<AddBackward0>)
# tensor(6.6882, grad_fn=<AddBackward0>)
# tensor(9.3869, grad_fn=<AddBackward0>)
# tensor(2.9556, grad_fn=<AddBackward0>)
# tensor(6.6805, grad_fn=<AddBackward0>)
# tensor(9.3548, grad_fn=<AddBackward0>)
# tensor(2.1375, grad_fn=<AddBackward0>)
# tensor(4.0944, grad_fn=<AddBackward0>)
# tensor(6.8306, grad_fn=<AddBackward0>)
# tensor(10.0737, grad_fn=<AddBackward0>)
# tensor(12.8988, grad_fn=<AddBackward0>)
# tensor(2.8007, grad_fn=<AddBackward0>)
# tensor(5.7305, grad_fn=<AddBackward0>)
# tensor(8.6356, grad_fn=<AddBackward0>)
# tensor(2.3174, grad_fn=<AddBackward0>)
# tensor(5.9654, grad_fn=<AddBackward0>)
# tensor(8.3083, grad_fn=<AddBackward0>)
# tensor(10.7380, grad_fn=<AddBackward0>)
# tensor(2.8137, grad_fn=<AddBackward0>)
# tensor(5.7074, grad_fn=<AddBackward0>)
# tensor(8.5679, grad_fn=<AddBackward0>)
# tensor(2.2931, grad_fn=<AddBackward0>)
# tensor(5.9470, grad_fn=<AddBackward0>)
# tensor(8.2767, grad_fn=<AddBackward0>)
# tensor(10.6967, grad_fn=<AddBackward0>)
# tensor(3.1612, grad_fn=<AddBackward0>)
# tensor(5.6289, grad_fn=<AddBackward0>)
# tensor(3.1684, grad_fn=<AddBackward0>)
# tensor(5.6292, grad_fn=<AddBackward0>)
# tensor(3.1712, grad_fn=<AddBackward0>)
# tensor(5.6222, grad_fn=<AddBackward0>)
# tensor(2.1176, grad_fn=<AddBackward0>)
# tensor(4.0718, grad_fn=<AddBackward0>)
# tensor(6.7698, grad_fn=<AddBackward0>)
# tensor(9.9842, grad_fn=<AddBackward0>)
# tensor(12.7363, grad_fn=<AddBackward0>)
# tensor(2.1147, grad_fn=<AddBackward0>)
# tensor(4.0651, grad_fn=<AddBackward0>)
# tensor(6.7517, grad_fn=<AddBackward0>)
# tensor(9.9567, grad_fn=<AddBackward0>)
# tensor(12.6957, grad_fn=<AddBackward0>)
# tensor(2.8938, grad_fn=<AddBackward0>)
# tensor(6.5994, grad_fn=<AddBackward0>)
# tensor(8.9005, grad_fn=<AddBackward0>)
# tensor(2.8308, grad_fn=<AddBackward0>)
# tensor(5.6290, grad_fn=<AddBackward0>)
# tensor(8.3226, grad_fn=<AddBackward0>)
# tensor(2.3111, grad_fn=<AddBackward0>)
# tensor(5.4875, grad_fn=<AddBackward0>)
# tensor(7.8511, grad_fn=<AddBackward0>)
# tensor(10.1793, grad_fn=<AddBackward0>)
# tensor(2.3101, grad_fn=<AddBackward0>)
# tensor(5.4804, grad_fn=<AddBackward0>)
# tensor(7.8394, grad_fn=<AddBackward0>)
# tensor(10.1655, grad_fn=<AddBackward0>)
# tensor(2.1017, grad_fn=<AddBackward0>)
# tensor(4.0463, grad_fn=<AddBackward0>)
# tensor(6.6767, grad_fn=<AddBackward0>)
# tensor(9.8044, grad_fn=<AddBackward0>)
# tensor(12.3808, grad_fn=<AddBackward0>)
# tensor(2.1976, grad_fn=<AddBackward0>)
# tensor(5.8905, grad_fn=<AddBackward0>)
# tensor(8.2115, grad_fn=<AddBackward0>)
# tensor(10.5535, grad_fn=<AddBackward0>)
# tensor(2.8445, grad_fn=<AddBackward0>)
# tensor(5.2870, grad_fn=<AddBackward0>)
# tensor(7.6098, grad_fn=<AddBackward0>)
# tensor(3.2152, grad_fn=<AddBackward0>)
# tensor(5.6044, grad_fn=<AddBackward0>)
# tensor(3.2423, grad_fn=<AddBackward0>)
# tensor(5.6622, grad_fn=<AddBackward0>)
# tensor(7.7271, grad_fn=<AddBackward0>)
# tensor(3.2143, grad_fn=<AddBackward0>)
# tensor(5.5976, grad_fn=<AddBackward0>)
# tensor(2.0915, grad_fn=<AddBackward0>)
# tensor(4.0376, grad_fn=<AddBackward0>)
# tensor(6.6244, grad_fn=<AddBackward0>)
# tensor(9.6633, grad_fn=<AddBackward0>)
# tensor(11.9386, grad_fn=<AddBackward0>)
# tensor(3.2049, grad_fn=<AddBackward0>)
# tensor(5.5998, grad_fn=<AddBackward0>)
# tensor(7.6260, grad_fn=<AddBackward0>)
# tensor(2.2908, grad_fn=<AddBackward0>)
# tensor(5.4313, grad_fn=<AddBackward0>)
# tensor(7.7341, grad_fn=<AddBackward0>)
# tensor(9.7578, grad_fn=<AddBackward0>)
# tensor(2.8484, grad_fn=<AddBackward0>)
# tensor(5.2439, grad_fn=<AddBackward0>)
# tensor(7.5522, grad_fn=<AddBackward0>)
# tensor(2.8465, grad_fn=<AddBackward0>)
# tensor(5.2327, grad_fn=<AddBackward0>)
# tensor(7.5400, grad_fn=<AddBackward0>)
# tensor(2.9415, grad_fn=<AddBackward0>)
# tensor(5.0004, grad_fn=<AddBackward0>)
# tensor(8.3713, grad_fn=<AddBackward0>)
# tensor(10.5987, grad_fn=<AddBackward0>)
# tensor(12.9404, grad_fn=<AddBackward0>)
# tensor(2.9235, grad_fn=<AddBackward0>)
# tensor(6.6007, grad_fn=<AddBackward0>)
# tensor(8.5672, grad_fn=<AddBackward0>)
# tensor(2.8276, grad_fn=<AddBackward0>)
# tensor(3.1056, grad_fn=<AddBackward0>)
# tensor(5.4330, grad_fn=<AddBackward0>)
# tensor(7.3764, grad_fn=<AddBackward0>)
# tensor(2.8070, grad_fn=<AddBackward0>)
# tensor(2.3270, grad_fn=<AddBackward0>)
# tensor(2.9049, grad_fn=<AddBackward0>)
# tensor(6.5760, grad_fn=<AddBackward0>)
# tensor(8.4868, grad_fn=<AddBackward0>)
# tensor(3.0301, grad_fn=<AddBackward0>)
# tensor(5.3289, grad_fn=<AddBackward0>)
# tensor(7.2280, grad_fn=<AddBackward0>)
# tensor(2.7671, grad_fn=<AddBackward0>)
# tensor(3.1553, grad_fn=<AddBackward0>)
# tensor(5.5594, grad_fn=<AddBackward0>)
# tensor(2.3590, grad_fn=<AddBackward0>)
# tensor(2.3601, grad_fn=<AddBackward0>)
# tensor(2.0945, grad_fn=<AddBackward0>)
# tensor(4.0535, grad_fn=<AddBackward0>)
# tensor(6.7314, grad_fn=<AddBackward0>)
# tensor(9.8165, grad_fn=<AddBackward0>)
# tensor(11.6756, grad_fn=<AddBackward0>)
# tensor(2.7381, grad_fn=<AddBackward0>)
# tensor(2.8849, grad_fn=<AddBackward0>)
# tensor(6.5420, grad_fn=<AddBackward0>)
# tensor(8.3857, grad_fn=<AddBackward0>)
# tensor(2.7786, grad_fn=<AddBackward0>)
# tensor(4.8725, grad_fn=<AddBackward0>)
# tensor(8.2742, grad_fn=<AddBackward0>)
# tensor(10.4114, grad_fn=<AddBackward0>)
# tensor(12.7694, grad_fn=<AddBackward0>)
# tensor(2.0944, grad_fn=<AddBackward0>)
# tensor(4.0554, grad_fn=<AddBackward0>)
# tensor(6.7345, grad_fn=<AddBackward0>)
# tensor(2.8628, grad_fn=<AddBackward0>)
# tensor(6.5134, grad_fn=<AddBackward0>)
# tensor(8.3435, grad_fn=<AddBackward0>)
# tensor(3.1628, grad_fn=<AddBackward0>)
# tensor(5.5675, grad_fn=<AddBackward0>)
# tensor(2.2159, grad_fn=<AddBackward0>)
# tensor(2.7097, grad_fn=<AddBackward0>)
# tensor(4.8072, grad_fn=<AddBackward0>)
# tensor(8.2064, grad_fn=<AddBackward0>)
# tensor(10.3325, grad_fn=<AddBackward0>)
# tensor(12.6864, grad_fn=<AddBackward0>)
# tensor(3.1735, grad_fn=<AddBackward0>)
# tensor(5.5742, grad_fn=<AddBackward0>)
# tensor(3.1748, grad_fn=<AddBackward0>)
# tensor(5.5732, grad_fn=<AddBackward0>)
# tensor(2.2088, grad_fn=<AddBackward0>)
# tensor(2.6786, grad_fn=<AddBackward0>)
# tensor(4.7727, grad_fn=<AddBackward0>)
# tensor(8.1619, grad_fn=<AddBackward0>)
# tensor(10.2858, grad_fn=<AddBackward0>)
# tensor(12.6249, grad_fn=<AddBackward0>)
# tensor(2.6702, grad_fn=<AddBackward0>)
# tensor(4.7626, grad_fn=<AddBackward0>)
# tensor(8.1481, grad_fn=<AddBackward0>)
# tensor(10.2716, grad_fn=<AddBackward0>)
# tensor(12.6061, grad_fn=<AddBackward0>)
# tensor(2.8210, grad_fn=<AddBackward0>)
# tensor(6.4528, grad_fn=<AddBackward0>)
# tensor(8.2471, grad_fn=<AddBackward0>)
# tensor(2.0771, grad_fn=<AddBackward0>)
# tensor(4.0506, grad_fn=<AddBackward0>)
# tensor(6.7107, grad_fn=<AddBackward0>)
# tensor(2.8001, grad_fn=<AddBackward0>)
# tensor(2.0711, grad_fn=<AddBackward0>)
# tensor(4.0457, grad_fn=<AddBackward0>)
# tensor(6.6993, grad_fn=<AddBackward0>)
# tensor(2.6114, grad_fn=<AddBackward0>)
# tensor(4.6971, grad_fn=<AddBackward0>)
# tensor(8.0653, grad_fn=<AddBackward0>)
# tensor(10.1850, grad_fn=<AddBackward0>)
# tensor(12.5037, grad_fn=<AddBackward0>)
# tensor(2.5991, grad_fn=<AddBackward0>)
# tensor(4.6831, grad_fn=<AddBackward0>)
# tensor(8.0485, grad_fn=<AddBackward0>)
# tensor(10.1671, grad_fn=<AddBackward0>)
# tensor(12.4838, grad_fn=<AddBackward0>)
# tensor(2.7658, grad_fn=<AddBackward0>)
# tensor(2.1786, grad_fn=<AddBackward0>)
# tensor(5.8427, grad_fn=<AddBackward0>)
# tensor(7.9590, grad_fn=<AddBackward0>)
# tensor(10.2864, grad_fn=<AddBackward0>)
# tensor(2.3780, grad_fn=<AddBackward0>)
# tensor(2.7323, grad_fn=<AddBackward0>)
# tensor(2.3657, grad_fn=<AddBackward0>)
# tensor(2.3545, grad_fn=<AddBackward0>)
# tensor(2.5847, grad_fn=<AddBackward0>)
# tensor(4.6419, grad_fn=<AddBackward0>)
# tensor(7.9740, grad_fn=<AddBackward0>)
# tensor(10.0964, grad_fn=<AddBackward0>)
# tensor(12.3717, grad_fn=<AddBackward0>)
# tensor(2.7234, grad_fn=<AddBackward0>)
# tensor(2.0323, grad_fn=<AddBackward0>)
# tensor(4.0023, grad_fn=<AddBackward0>)
# tensor(6.6170, grad_fn=<AddBackward0>)
# tensor(2.6738, grad_fn=<AddBackward0>)
# tensor(2.7300, grad_fn=<AddBackward0>)
# tensor(3.2994, grad_fn=<AddBackward0>)
# tensor(5.6039, grad_fn=<AddBackward0>)
# tensor(3.2995, grad_fn=<AddBackward0>)
# tensor(5.6027, grad_fn=<AddBackward0>)
# tensor(2.7647, grad_fn=<AddBackward0>)
# tensor(6.3845, grad_fn=<AddBackward0>)
# tensor(8.5488, grad_fn=<AddBackward0>)
# tensor(2.7180, grad_fn=<AddBackward0>)
# tensor(2.7108, grad_fn=<AddBackward0>)
# tensor(2.7607, grad_fn=<AddBackward0>)
# tensor(6.3750, grad_fn=<AddBackward0>)
# tensor(8.5327, grad_fn=<AddBackward0>)
# tensor(3.2758, grad_fn=<AddBackward0>)
# tensor(5.5875, grad_fn=<AddBackward0>)
# tensor(2.6174, grad_fn=<AddBackward0>)
# tensor(3.2599, grad_fn=<AddBackward0>)
# tensor(5.5792, grad_fn=<AddBackward0>)
# tensor(2.7524, grad_fn=<AddBackward0>)
# tensor(6.3531, grad_fn=<AddBackward0>)
# tensor(8.4999, grad_fn=<AddBackward0>)
# tensor(2.3494, grad_fn=<AddBackward0>)
# tensor(2.4984, grad_fn=<AddBackward0>)
# tensor(4.5615, grad_fn=<AddBackward0>)
# tensor(7.8757, grad_fn=<AddBackward0>)
# tensor(9.9877, grad_fn=<AddBackward0>)
# tensor(12.2422, grad_fn=<AddBackward0>)
# tensor(3.2394, grad_fn=<AddBackward0>)
# tensor(5.5617, grad_fn=<AddBackward0>)
# tensor(2.4890, grad_fn=<AddBackward0>)
# tensor(4.5554, grad_fn=<AddBackward0>)
# tensor(7.8652, grad_fn=<AddBackward0>)
# tensor(9.9772, grad_fn=<AddBackward0>)
# tensor(12.2262, grad_fn=<AddBackward0>)
# tensor(2.4814, grad_fn=<AddBackward0>)
# tensor(4.5495, grad_fn=<AddBackward0>)
# tensor(7.8566, grad_fn=<AddBackward0>)
# tensor(9.9678, grad_fn=<AddBackward0>)
# tensor(12.2144, grad_fn=<AddBackward0>)
# tensor(3.2268, grad_fn=<AddBackward0>)
# tensor(5.5476, grad_fn=<AddBackward0>)
# tensor(2.0041, grad_fn=<AddBackward0>)
# tensor(3.9839, grad_fn=<AddBackward0>)
# tensor(7.2032, grad_fn=<AddBackward0>)
# tensor(10.2661, grad_fn=<AddBackward0>)
# tensor(2.7419, grad_fn=<AddBackward0>)
# tensor(6.3139, grad_fn=<AddBackward0>)
# tensor(8.4333, grad_fn=<AddBackward0>)
# tensor(1.9992, grad_fn=<AddBackward0>)
# tensor(3.9796, grad_fn=<AddBackward0>)
# tensor(7.1973, grad_fn=<AddBackward0>)
# tensor(10.2492, grad_fn=<AddBackward0>)
# tensor(3.2092, grad_fn=<AddBackward0>)
# tensor(5.5287, grad_fn=<AddBackward0>)
# tensor(2.7376, grad_fn=<AddBackward0>)
# tensor(6.3002, grad_fn=<AddBackward0>)
# tensor(8.4102, grad_fn=<AddBackward0>)
# tensor(1.9902, grad_fn=<AddBackward0>)
# tensor(3.9670, grad_fn=<AddBackward0>)
# tensor(7.1790, grad_fn=<AddBackward0>)
# tensor(10.2035, grad_fn=<AddBackward0>)
# tensor(3.1983, grad_fn=<AddBackward0>)
# tensor(5.5144, grad_fn=<AddBackward0>)
# tensor(1.9841, grad_fn=<AddBackward0>)
# tensor(3.9566, grad_fn=<AddBackward0>)
# tensor(7.1629, grad_fn=<AddBackward0>)
# tensor(10.1610, grad_fn=<AddBackward0>)
# tensor(2.7299, grad_fn=<AddBackward0>)
# tensor(6.2797, grad_fn=<AddBackward0>)
# tensor(8.3778, grad_fn=<AddBackward0>)
# tensor(2.1389, grad_fn=<AddBackward0>)
# tensor(5.7929, grad_fn=<AddBackward0>)
# tensor(7.8813, grad_fn=<AddBackward0>)
# tensor(10.1443, grad_fn=<AddBackward0>)
# tensor(1.9756, grad_fn=<AddBackward0>)
# tensor(3.9410, grad_fn=<AddBackward0>)
# tensor(7.1373, grad_fn=<AddBackward0>)
# tensor(10.0829, grad_fn=<AddBackward0>)
# tensor(2.1308, grad_fn=<AddBackward0>)
# tensor(5.7872, grad_fn=<AddBackward0>)
# tensor(7.8777, grad_fn=<AddBackward0>)
# tensor(10.1278, grad_fn=<AddBackward0>)
# tensor(2.5737, grad_fn=<AddBackward0>)
# tensor(2.5712, grad_fn=<AddBackward0>)
# tensor(2.1134, grad_fn=<AddBackward0>)
# tensor(5.7745, grad_fn=<AddBackward0>)
# tensor(7.8692, grad_fn=<AddBackward0>)
# tensor(10.0943, grad_fn=<AddBackward0>)
# tensor(2.4376, grad_fn=<AddBackward0>)
# tensor(4.5006, grad_fn=<AddBackward0>)
# tensor(7.7648, grad_fn=<AddBackward0>)
# tensor(9.8911, grad_fn=<AddBackward0>)
# tensor(12.0569, grad_fn=<AddBackward0>)
# tensor(1.9608, grad_fn=<AddBackward0>)
# tensor(3.9179, grad_fn=<AddBackward0>)
# tensor(7.1023, grad_fn=<AddBackward0>)
# tensor(9.9237, grad_fn=<AddBackward0>)
# tensor(2.6211, grad_fn=<AddBackward0>)
# tensor(2.6158, grad_fn=<AddBackward0>)
# tensor(2.3728, grad_fn=<AddBackward0>)
# tensor(2.7203, grad_fn=<AddBackward0>)
# tensor(6.2418, grad_fn=<AddBackward0>)
# tensor(8.3156, grad_fn=<AddBackward0>)
# tensor(2.3750, grad_fn=<AddBackward0>)
# tensor(3.2036, grad_fn=<AddBackward0>)
# tensor(5.4555, grad_fn=<AddBackward0>)
# tensor(1.9493, grad_fn=<AddBackward0>)
# tensor(3.9052, grad_fn=<AddBackward0>)
# tensor(7.0793, grad_fn=<AddBackward0>)
# tensor(9.2538, grad_fn=<AddBackward0>)
# tensor(11.3086, grad_fn=<AddBackward0>)
# tensor(2.3594, grad_fn=<AddBackward0>)
# tensor(2.7176, grad_fn=<AddBackward0>)
# tensor(6.2251, grad_fn=<AddBackward0>)
# tensor(8.2898, grad_fn=<AddBackward0>)
# tensor(2.5378, grad_fn=<AddBackward0>)
# tensor(2.4512, grad_fn=<AddBackward0>)
# tensor(4.4937, grad_fn=<AddBackward0>)
# tensor(7.7172, grad_fn=<AddBackward0>)
# tensor(9.8701, grad_fn=<AddBackward0>)
# tensor(11.9643, grad_fn=<AddBackward0>)
# tensor(1.9462, grad_fn=<AddBackward0>)
# tensor(3.9018, grad_fn=<AddBackward0>)
# tensor(7.0677, grad_fn=<AddBackward0>)
# tensor(9.2423, grad_fn=<AddBackward0>)
# tensor(11.2832, grad_fn=<AddBackward0>)
# tensor(3.2273, grad_fn=<AddBackward0>)
# tensor(5.4334, grad_fn=<AddBackward0>)
# tensor(2.3225, grad_fn=<AddBackward0>)
# tensor(2.5247, grad_fn=<AddBackward0>)
# tensor(2.0675, grad_fn=<AddBackward0>)
# tensor(5.7597, grad_fn=<AddBackward0>)
# tensor(7.8853, grad_fn=<AddBackward0>)
# tensor(9.9754, grad_fn=<AddBackward0>)
# tensor(2.5165, grad_fn=<AddBackward0>)
# tensor(2.7166, grad_fn=<AddBackward0>)
# tensor(6.1994, grad_fn=<AddBackward0>)
# tensor(8.2428, grad_fn=<AddBackward0>)
# tensor(1.9434, grad_fn=<AddBackward0>)
# tensor(3.9022, grad_fn=<AddBackward0>)
# tensor(7.0583, grad_fn=<AddBackward0>)
# tensor(9.2304, grad_fn=<AddBackward0>)
# tensor(11.2500, grad_fn=<AddBackward0>)
# tensor(2.4744, grad_fn=<AddBackward0>)
# tensor(4.5057, grad_fn=<AddBackward0>)
# tensor(7.6897, grad_fn=<AddBackward0>)
# tensor(9.8698, grad_fn=<AddBackward0>)
# tensor(11.9115, grad_fn=<AddBackward0>)
# tensor(2.0570, grad_fn=<AddBackward0>)
# tensor(5.7588, grad_fn=<AddBackward0>)
# tensor(7.8916, grad_fn=<AddBackward0>)
# tensor(9.9500, grad_fn=<AddBackward0>)
# tensor(2.6341, grad_fn=<AddBackward0>)
# tensor(2.2874, grad_fn=<AddBackward0>)
# tensor(1.9404, grad_fn=<AddBackward0>)
# tensor(3.9069, grad_fn=<AddBackward0>)
# tensor(7.0591, grad_fn=<AddBackward0>)
# tensor(9.2219, grad_fn=<AddBackward0>)
# tensor(11.2274, grad_fn=<AddBackward0>)
# tensor(1.9394, grad_fn=<AddBackward0>)
# tensor(3.9068, grad_fn=<AddBackward0>)
# tensor(7.0574, grad_fn=<AddBackward0>)
# tensor(9.2183, grad_fn=<AddBackward0>)
# tensor(11.2212, grad_fn=<AddBackward0>)
# tensor(2.2805, grad_fn=<AddBackward0>)
# tensor(3.2364, grad_fn=<AddBackward0>)
# tensor(5.3819, grad_fn=<AddBackward0>)
# tensor(2.0521, grad_fn=<AddBackward0>)
# tensor(5.7538, grad_fn=<AddBackward0>)
# tensor(7.8818, grad_fn=<AddBackward0>)
# tensor(9.9095, grad_fn=<AddBackward0>)
# tensor(2.2632, grad_fn=<AddBackward0>)
# tensor(2.0457, grad_fn=<AddBackward0>)
# tensor(5.7479, grad_fn=<AddBackward0>)
# tensor(7.8746, grad_fn=<AddBackward0>)
# tensor(9.8934, grad_fn=<AddBackward0>)
# tensor(2.7260, grad_fn=<AddBackward0>)
# tensor(6.1849, grad_fn=<AddBackward0>)
# tensor(8.1984, grad_fn=<AddBackward0>)
# tensor(2.6451, grad_fn=<AddBackward0>)
# tensor(2.0353, grad_fn=<AddBackward0>)
# tensor(5.7322, grad_fn=<AddBackward0>)
# tensor(7.8523, grad_fn=<AddBackward0>)
# tensor(9.8617, grad_fn=<AddBackward0>)
# tensor(2.6448, grad_fn=<AddBackward0>)
# tensor(2.6401, grad_fn=<AddBackward0>)
# tensor(2.4705, grad_fn=<AddBackward0>)
# tensor(1.9288, grad_fn=<AddBackward0>)
# tensor(3.9136, grad_fn=<AddBackward0>)
# tensor(7.0546, grad_fn=<AddBackward0>)
# tensor(9.1881, grad_fn=<AddBackward0>)
# tensor(11.1599, grad_fn=<AddBackward0>)
# tensor(2.4639, grad_fn=<AddBackward0>)
# tensor(3.2276, grad_fn=<AddBackward0>)
# tensor(5.3577, grad_fn=<AddBackward0>)
# tensor(1.9282, grad_fn=<AddBackward0>)
# tensor(3.9168, grad_fn=<AddBackward0>)
# tensor(7.0549, grad_fn=<AddBackward0>)
# tensor(9.1830, grad_fn=<AddBackward0>)
# tensor(11.1485, grad_fn=<AddBackward0>)
# tensor(2.7316, grad_fn=<AddBackward0>)
# tensor(6.1740, grad_fn=<AddBackward0>)
# tensor(8.1688, grad_fn=<AddBackward0>)
# tensor(2.4450, grad_fn=<AddBackward0>)
# tensor(2.0579, grad_fn=<AddBackward0>)
# tensor(5.7116, grad_fn=<AddBackward0>)
# tensor(7.8044, grad_fn=<AddBackward0>)
# tensor(9.7974, grad_fn=<AddBackward0>)
# tensor(2.5724, grad_fn=<AddBackward0>)
# tensor(2.2546, grad_fn=<AddBackward0>)
# tensor(2.5579, grad_fn=<AddBackward0>)
# tensor(2.3875, grad_fn=<AddBackward0>)
# tensor(4.4209, grad_fn=<AddBackward0>)
# tensor(7.5917, grad_fn=<AddBackward0>)
# tensor(9.7425, grad_fn=<AddBackward0>)
# tensor(11.7155, grad_fn=<AddBackward0>)
# tensor(2.5309, grad_fn=<AddBackward0>)
# tensor(1.9292, grad_fn=<AddBackward0>)
# tensor(3.9302, grad_fn=<AddBackward0>)
# tensor(7.0596, grad_fn=<AddBackward0>)
# tensor(9.1742, grad_fn=<AddBackward0>)
# tensor(11.1188, grad_fn=<AddBackward0>)
# tensor(2.7374, grad_fn=<AddBackward0>)
# tensor(6.1639, grad_fn=<AddBackward0>)
# tensor(8.1427, grad_fn=<AddBackward0>)
# tensor(1.9282, grad_fn=<AddBackward0>)
# tensor(3.9318, grad_fn=<AddBackward0>)
# tensor(7.0588, grad_fn=<AddBackward0>)
# tensor(9.1701, grad_fn=<AddBackward0>)
# tensor(11.1102, grad_fn=<AddBackward0>)
# tensor(1.9272, grad_fn=<AddBackward0>)
# tensor(3.9315, grad_fn=<AddBackward0>)
# tensor(7.0562, grad_fn=<AddBackward0>)
# tensor(9.1662, grad_fn=<AddBackward0>)
# tensor(11.1038, grad_fn=<AddBackward0>)
# tensor(2.2498, grad_fn=<AddBackward0>)
# tensor(4.3910, grad_fn=<AddBackward0>)
# tensor(7.3993, grad_fn=<AddBackward0>)
# tensor(9.6201, grad_fn=<AddBackward0>)
# tensor(11.5829, grad_fn=<AddBackward0>)
# tensor(2.4051, grad_fn=<AddBackward0>)
# tensor(2.4018, grad_fn=<AddBackward0>)
# tensor(2.3939, grad_fn=<AddBackward0>)
# tensor(2.3595, grad_fn=<AddBackward0>)
# tensor(5.3883, grad_fn=<AddBackward0>)
# tensor(7.9361, grad_fn=<AddBackward0>)
# tensor(2.3425, grad_fn=<AddBackward0>)
# tensor(5.3299, grad_fn=<AddBackward0>)
# tensor(7.8730, grad_fn=<AddBackward0>)
# tensor(2.1623, grad_fn=<AddBackward0>)
# tensor(5.7583, grad_fn=<AddBackward0>)
# tensor(7.8650, grad_fn=<AddBackward0>)
# tensor(9.7997, grad_fn=<AddBackward0>)
# tensor(3.0182, grad_fn=<AddBackward0>)
# tensor(5.1675, grad_fn=<AddBackward0>)
# tensor(2.7398, grad_fn=<AddBackward0>)
# tensor(6.1674, grad_fn=<AddBackward0>)
# tensor(8.1211, grad_fn=<AddBackward0>)
# tensor(2.2791, grad_fn=<AddBackward0>)
# tensor(5.0304, grad_fn=<AddBackward0>)
# tensor(7.1950, grad_fn=<AddBackward0>)
# tensor(2.1668, grad_fn=<AddBackward0>)
# tensor(5.6460, grad_fn=<AddBackward0>)
# tensor(7.7445, grad_fn=<AddBackward0>)
# tensor(9.6684, grad_fn=<AddBackward0>)
# tensor(1.9203, grad_fn=<AddBackward0>)
# tensor(3.9358, grad_fn=<AddBackward0>)
# tensor(2.1682, grad_fn=<AddBackward0>)
# tensor(5.5172, grad_fn=<AddBackward0>)
# tensor(7.6125, grad_fn=<AddBackward0>)
# tensor(9.5304, grad_fn=<AddBackward0>)
# tensor(2.1687, grad_fn=<AddBackward0>)
# tensor(5.4130, grad_fn=<AddBackward0>)
# tensor(7.5058, grad_fn=<AddBackward0>)
# tensor(9.4218, grad_fn=<AddBackward0>)
# tensor(2.0335, grad_fn=<AddBackward0>)
# tensor(4.0987, grad_fn=<AddBackward0>)
# tensor(7.1950, grad_fn=<AddBackward0>)
# tensor(9.3482, grad_fn=<AddBackward0>)
# tensor(11.2619, grad_fn=<AddBackward0>)
# tensor(2.6572, grad_fn=<AddBackward0>)
# tensor(5.9042, grad_fn=<AddBackward0>)
# tensor(7.9743, grad_fn=<AddBackward0>)
# tensor(9.9290, grad_fn=<AddBackward0>)
# tensor(2.3871, grad_fn=<AddBackward0>)
# tensor(1.9155, grad_fn=<AddBackward0>)
# tensor(3.9422, grad_fn=<AddBackward0>)
# tensor(2.3684, grad_fn=<AddBackward0>)
# tensor(2.9718, grad_fn=<AddBackward0>)
# tensor(5.0371, grad_fn=<AddBackward0>)
# tensor(1.9137, grad_fn=<AddBackward0>)
# tensor(3.9437, grad_fn=<AddBackward0>)
# tensor(2.7473, grad_fn=<AddBackward0>)
# tensor(6.2027, grad_fn=<AddBackward0>)
# tensor(8.1115, grad_fn=<AddBackward0>)
# tensor(2.0028, grad_fn=<AddBackward0>)
# tensor(4.0385, grad_fn=<AddBackward0>)
# tensor(7.1836, grad_fn=<AddBackward0>)
# tensor(9.2949, grad_fn=<AddBackward0>)
# tensor(2.3868, grad_fn=<AddBackward0>)
# tensor(5.5666, grad_fn=<AddBackward0>)
# tensor(8.0148, grad_fn=<AddBackward0>)
# tensor(9.9762, grad_fn=<AddBackward0>)
# tensor(2.9572, grad_fn=<AddBackward0>)
# tensor(5.0105, grad_fn=<AddBackward0>)

# %%
y[i]
# Out:
# tensor([1])

# %%
# 测试函数
def translate(s):
    t = [lan1(i) for i in s.split()]
    t.append(EOS_token)
    print(t)
    f = encoder.sample(t)   # 编码
    s = decoder.sample(f)   # 解码
    r = [lan2.idx2word[i] for i in s]    # 根据id得到单词
    return ' '.join(r) # 生成句子
print(translate('are you ok .'))
# print(translate('我们 打 游戏 。'))
# Out:
# [2, 2, 2, 4, 1]
# <SOS> 了 。 我 我 <EOS>
